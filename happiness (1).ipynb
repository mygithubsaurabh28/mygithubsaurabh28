# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
data=pd.read_csv(r"E:\data trained projects\happiness_score_dataset.csv")

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
data.shape
# Out:
# (158, 12)

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %%
data=data.drop(columns=['Region'])

# %%
data
# Out:
#          Country  Happiness Rank  Happiness Score  Standard Error  \
# 0    Switzerland               1            7.587         0.03411
# 1        Iceland               2            7.561         0.04884
# 2        Denmark               3            7.527         0.03328
# 3         Norway               4            7.522         0.03880
# 4         Canada               5            7.427         0.03553
# ..           ...             ...              ...             ...
# 153       Rwanda             154            3.465         0.03464
# 154        Benin             155            3.340         0.03656
# 155        Syria             156            3.006         0.05015
# 156      Burundi             157            2.905         0.08658
# 157         Togo             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726
#
# [158 rows x 11 columns]

# %%
x=['Happiness Rank','Happiness Score','Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']
x
# Out:
# ['Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
plt.figure(figsize=(25,25))
graph=1
for column in x:
    if graph<=10:
        ax=plt.subplot(6,4,graph)
        sns.boxplot(data[column],orient='v')
        plt.xlabel(column,fontsize=15)
    graph+=1
plt.show()

# %%
q1=data['Standard Error'].quantile(0.25)
q3=data['Standard Error'].quantile(0.85)
q1,q3
# Out:
# (0.0372675, 0.061439499999999994)

# %%
iqr=q3-q1

# %%
q1=data['Family'].quantile(0.25)
q3=data['Family'].quantile(0.85)
q1,q3
# Out:
# (0.8568225, 1.2624769999999998)

# %%
q1=data['Trust (Government Corruption)'].quantile(0.25)
q3=data['Trust (Government Corruption)'].quantile(0.85)
q1,q3
# Out:
# (0.061675, 0.28374099999999997)

# %%
q1=data['Generosity'].quantile(0.25)
q3=data['Generosity'].quantile(0.85)
q1,q3
# Out:
# (0.1505525, 0.36373599999999995)

# %%
q1=data['Dystopia Residual'].quantile(0.25)
q3=data['Dystopia Residual'].quantile(0.85)
q1,q3
# Out:
# (1.75941, 2.6887054999999997)

# %%
lower_limit= q1-1.5*iqr
upper_limit= q3+1.5*iqr

# %%
no_outlier_standard=data[(data['Standard Error']<lower_limit)|(data['Standard Error']>upper_limit)]

# %%
data['Standard Error']=no_outlier_standard

# %%
no_outlier_Family=data[(data['Family']<lower_limit)|(data['Family']>upper_limit)]

# %%
data['Family']=no_outlier_Family

# %%
no_outlier_Trust=data[(data['Trust (Government Corruption)']<lower_limit)|(data['Trust (Government Corruption)']>upper_limit)]

# %%
data['Trust (Government Corruption)']=no_outlier_Trust

# %%
no_outlier_Generosity=data[(data['Generosity']<lower_limit)|(data['Generosity']>upper_limit)]

# %%
data['Generosity']=no_outlier_Generosity

# %%
no_outlier_Dystopia=data[(data['Dystopia Residual']<lower_limit)|(data['Dystopia Residual']>upper_limit)]

# %%
data['Dystopia Residual']=no_outlier_Dystopia

# %%
data
# Out:
#          Country  Happiness Rank  Happiness Score Standard Error  \
# 0    Switzerland               1            7.587    Switzerland
# 1        Iceland               2            7.561        Iceland
# 2        Denmark               3            7.527        Denmark
# 3         Norway               4            7.522         Norway
# 4         Canada               5            7.427         Canada
# ..           ...             ...              ...            ...
# 153       Rwanda             154            3.465         Rwanda
# 154        Benin             155            3.340          Benin
# 155        Syria             156            3.006          Syria
# 156      Burundi             157            2.905        Burundi
# 157         Togo             158            2.839           Togo
#
#      Economy (GDP per Capita)       Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  Switzerland                   0.94143  0.66557
# 1                     1.30232      Iceland                   0.94784  0.62877
# 2                     1.32548      Denmark                   0.87464  0.64938
# 3                     1.45900       Norway                   0.88521  0.66973
# 4                     1.32629       Canada                   0.90563  0.63297
# ..                        ...          ...                       ...      ...
# 153                   0.22208       Rwanda                   0.42864  0.59201
# 154                   0.28665        Benin                   0.31910  0.48450
# 155                   0.66320        Syria                   0.72193  0.15684
# 156                   0.01530      Burundi                   0.22396  0.11850
# 157                   0.20868         Togo                   0.28443  0.36453
#
#     Trust (Government Corruption)   Generosity Dystopia Residual
# 0                     Switzerland  Switzerland               NaN
# 1                         Iceland      Iceland               NaN
# 2                         Denmark      Denmark               NaN
# 3                          Norway       Norway               NaN
# 4                          Canada       Canada               NaN
# ..                            ...          ...               ...
# 153                        Rwanda       Rwanda            Rwanda
# 154                         Benin        Benin             Benin
# 155                         Syria        Syria             Syria
# 156                       Burundi      Burundi               NaN
# 157                          Togo         Togo              Togo
#
# [158 rows x 11 columns]
